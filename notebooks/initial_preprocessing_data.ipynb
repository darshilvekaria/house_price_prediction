# %% [markdown]
# predict median house values in Californian districts, given a number of features from these districts

# %%
import pandas as pd

housing = pd.read_csv(r"..\datasets\housing\housing.csv")

# %%
housing.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
housing["ocean_proximity"].value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: count, dtype: int64

# %%
housing.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# 25%        296.000000    787.000000    280.000000       2.563400
# 50%        435.000000   1166.000000    409.000000       3.534800
# 75%        647.000000   1725.000000    605.000000       4.743250
# max       6445.000000  35682.000000   6082.000000      15.000100
#
#        median_house_value
# count        20640.000000
# mean        206855.816909
# std         115395.615874
# min          14999.000000
# 25%         119600.000000
# 50%         179700.000000
# 75%         264725.000000
# max         500001.000000

# %% [markdown]
# Use nomimatim reverse geocoding to fetch county/district name for given lat long

# %%
import requests
import time
import pickle
import os

# Load cache if it exists
cache_file = "..\model_assets/district_cache.pkl"
if os.path.exists(cache_file):
    with open(cache_file, "rb") as f:  
        cache = pickle.load(f)
else:
    cache = {}

# Function to call Nominatim reverse geocoding API
def get_district(lat, lon):
    key = (round(lat, 2), round(lon, 2)) # coordinates round off upto two decimals. All coords are within two decimals in raw dataset

    if key in cache:
        return cache[key]

    url = "https://nominatim.openstreetmap.org/reverse"
    params = {
        "lat": lat,
        "lon": lon,
        "format": "json",
        "zoom": 10, # 10 usually returns a district/county level. Lower = broader (e.g., country), higher = more specific (e.g., house).
        "addressdetails": 1 # 1 returns a dictionary of address components (like city, state, district).
    }
    headers = {
        "User-Agent": "darshilvekaria11@gmail.com"  # Required per Nominatim policy
    }

    response = requests.get(url, params=params, headers=headers)
    if response.status_code == 200:
        data = response.json()
        district = data.get("address", {}).get("county") or data.get("address", {}).get("state_district")
    else:
        district = None

    cache[key] = district

    # Save updated cache
    with open(cache_file, "wb") as f:
        pickle.dump(cache, f)

    time.sleep(0.5)  # Nominatim policy: 1 request/sec max
    return district

# Add a new column with district name
districts = []
for idx, row in housing.iterrows():
    district = get_district(row["latitude"], row["longitude"])
    districts.append(district)

    # Print progress every 100 rows
    if (idx + 1) % 100 == 0 or (idx + 1) == len(housing):
        print(f"[{idx + 1}/{len(housing)}] Coordinates: ({row['latitude']}, {row['longitude']}) -> District: {district}")


housing["district"] = districts

# Save the updated CSV
housing.loc[~housing['district'].isna()].to_csv(r"..\datasets\housing\housing_with_districts.csv", index=False)
# Out:
# [100/20640] Coordinates: (37.82, -122.26) -> District: Alameda County
# [200/20640] Coordinates: (32.8, -116.94) -> District: San Diego County
# [300/20640] Coordinates: (33.63, -117.92) -> District: Orange County
# [400/20640] Coordinates: (37.38, -122.05) -> District: Santa Clara County
# [500/20640] Coordinates: (37.56, -122.31) -> District: San Mateo County
# [600/20640] Coordinates: (36.91, -121.76) -> District: Santa Cruz County
# [700/20640] Coordinates: (33.97, -118.16) -> District: Los Angeles County
# [800/20640] Coordinates: (34.05, -117.27) -> District: San Bernardino County
# [900/20640] Coordinates: (34.07, -118.45) -> District: Los Angeles County
# [1000/20640] Coordinates: (34.15, -118.13) -> District: Los Angeles County
# [1100/20640] Coordinates: (37.63, -122.08) -> District: Alameda County
# [1200/20640] Coordinates: (40.57, -122.4) -> District: Shasta County
# [1300/20640] Coordinates: (33.73, -117.93) -> District: Orange County
# [1400/20640] Coordinates: (33.91, -118.17) -> District: Los Angeles County
# [1500/20640] Coordinates: (34.18, -118.32) -> District: Los Angeles County
# [1600/20640] Coordinates: (33.89, -117.82) -> District: Orange County
# [1700/20640] Coordinates: (33.78, -117.96) -> District: Orange County
# [1800/20640] Coordinates: (39.07, -122.91) -> District: Lake County
# [1900/20640] Coordinates: (36.59, -119.43) -> District: Fresno County
# [2000/20640] Coordinates: (34.08, -117.48) -> District: San Bernardino County
# [2100/20640] Coordinates: (34.96, -120.43) -> District: Santa Barbara County
# [2200/20640] Coordinates: (38.4, -121.38) -> District: Sacramento County
# [2300/20640] Coordinates: (37.31, -121.98) -> District: Santa Clara County
# [2400/20640] Coordinates: (33.78, -118.17) -> District: Los Angeles County
# [2500/20640] Coordinates: (32.74, -117.02) -> District: San Diego County
# [2600/20640] Coordinates: (38.93, -119.99) -> District: El Dorado County
# [2700/20640] Coordinates: (37.87, -122.03) -> District: Contra Costa County
# [2800/20640] Coordinates: (34.16, -118.37) -> District: Los Angeles County
# [2900/20640] Coordinates: (37.57, -122.32) -> District: San Mateo County
# [3000/20640] Coordinates: (37.28, -121.94) -> District: Santa Clara County
# [3100/20640] Coordinates: (34.09, -118.37) -> District: Los Angeles County
# [3200/20640] Coordinates: (38.61, -122.86) -> District: Sonoma County
# [3300/20640] Coordinates: (38.86, -121.12) -> District: Placer County
# [3400/20640] Coordinates: (38.6, -121.33) -> District: Sacramento County
# [3500/20640] Coordinates: (36.98, -121.99) -> District: Santa Cruz County
# [3600/20640] Coordinates: (37.81, -122.26) -> District: Alameda County
# [3700/20640] Coordinates: (36.6, -121.86) -> District: Monterey County
# [3800/20640] Coordinates: (33.74, -117.9) -> District: Orange County
# [3900/20640] Coordinates: (38.97, -122.78) -> District: Lake County
# [4000/20640] Coordinates: (37.3, -122.03) -> District: Santa Clara County
# [4100/20640] Coordinates: (37.97, -122.01) -> District: Contra Costa County
# [4200/20640] Coordinates: (37.38, -121.87) -> District: Santa Clara County
# [4300/20640] Coordinates: (34.19, -118.53) -> District: Los Angeles County
# [4400/20640] Coordinates: (33.71, -118.29) -> District: Los Angeles County
# [4500/20640] Coordinates: (37.74, -120.95) -> District: San Joaquin County
# [4600/20640] Coordinates: (33.15, -117.34) -> District: San Diego County
# [4700/20640] Coordinates: (33.72, -118.3) -> District: Los Angeles County
# [4800/20640] Coordinates: (38.56, -121.43) -> District: Sacramento County
# [4900/20640] Coordinates: (32.78, -117.16) -> District: San Diego County
# [5000/20640] Coordinates: (34.23, -118.42) -> District: Los Angeles County
# [5100/20640] Coordinates: (34.26, -119.02) -> District: Ventura County
# [5200/20640] Coordinates: (32.76, -115.39) -> District: Imperial County
# [5300/20640] Coordinates: (33.77, -118.02) -> District: Orange County
# [5400/20640] Coordinates: (37.72, -122.15) -> District: Alameda County
# [5500/20640] Coordinates: (36.96, -120.07) -> District: Madera County
# [5600/20640] Coordinates: (37.32, -121.03) -> District: Stanislaus County
# [5700/20640] Coordinates: (33.97, -118.35) -> District: Los Angeles County
# [5800/20640] Coordinates: (39.71, -121.89) -> District: Butte County
# [5900/20640] Coordinates: (37.28, -121.95) -> District: Santa Clara County
# [6000/20640] Coordinates: (34.09, -118.41) -> District: Los Angeles County
# [6100/20640] Coordinates: (37.74, -122.16) -> District: Alameda County
# [6200/20640] Coordinates: (37.66, -122.09) -> District: Alameda County
# [6300/20640] Coordinates: (33.8, -118.11) -> District: Los Angeles County
# [6400/20640] Coordinates: (33.8, -118.38) -> District: Los Angeles County
# [6500/20640] Coordinates: (34.4, -118.9) -> District: Ventura County
# [6600/20640] Coordinates: (34.06, -118.05) -> District: Los Angeles County
# [6700/20640] Coordinates: (33.87, -117.57) -> District: Riverside County
# [6800/20640] Coordinates: (34.2, -118.45) -> District: Los Angeles County
# [6900/20640] Coordinates: (38.01, -121.93) -> District: Contra Costa County
# [7000/20640] Coordinates: (38.59, -121.38) -> District: Sacramento County
# [7100/20640] Coordinates: (32.92, -117.14) -> District: San Diego County
# [7200/20640] Coordinates: (37.4, -122.12) -> District: Santa Clara County
# [7300/20640] Coordinates: (34.02, -118.16) -> District: Los Angeles County
# [7400/20640] Coordinates: (34.04, -118.32) -> District: Los Angeles County
# [7500/20640] Coordinates: (33.55, -117.27) -> District: Riverside County
# [7600/20640] Coordinates: (37.9, -122.27) -> District: Alameda County
# [7700/20640] Coordinates: (33.76, -117.87) -> District: Orange County
# [7800/20640] Coordinates: (33.62, -117.74) -> District: Orange County
# [7900/20640] Coordinates: (34.15, -118.09) -> District: Los Angeles County
# [8000/20640] Coordinates: (37.73, -120.93) -> District: Stanislaus County
# [8100/20640] Coordinates: (37.63, -121.0) -> District: Stanislaus County
# [8200/20640] Coordinates: (34.11, -118.3) -> District: Los Angeles County
# [8300/20640] Coordinates: (34.44, -119.73) -> District: Santa Barbara County
# [8400/20640] Coordinates: (34.3, -118.44) -> District: Los Angeles County
# [8500/20640] Coordinates: (34.14, -117.88) -> District: Los Angeles County
# [8600/20640] Coordinates: (38.52, -121.46) -> District: Sacramento County
# [8700/20640] Coordinates: (34.07, -118.36) -> District: Los Angeles County
# [8800/20640] Coordinates: (37.79, -122.5) -> District: None
# [8900/20640] Coordinates: (37.59, -122.34) -> District: San Mateo County
# [9000/20640] Coordinates: (37.78, -121.95) -> District: Contra Costa County
# [9100/20640] Coordinates: (33.95, -118.03) -> District: Los Angeles County
# [9200/20640] Coordinates: (34.13, -117.37) -> District: San Bernardino County
# [9300/20640] Coordinates: (36.87, -121.77) -> District: Monterey County
# [9400/20640] Coordinates: (38.59, -121.35) -> District: Sacramento County
# [9500/20640] Coordinates: (38.5, -120.65) -> District: Amador County
# [9600/20640] Coordinates: (38.67, -121.37) -> District: Sacramento County
# [9700/20640] Coordinates: (34.21, -118.33) -> District: Los Angeles County
# [9800/20640] Coordinates: (33.05, -117.24) -> District: San Diego County
# [9900/20640] Coordinates: (34.0, -118.41) -> District: Los Angeles County
# [10000/20640] Coordinates: (38.59, -121.4) -> District: Sacramento County
# [10100/20640] Coordinates: (37.43, -122.19) -> District: Santa Clara County
# [10200/20640] Coordinates: (37.72, -122.13) -> District: Alameda County
# [10300/20640] Coordinates: (34.0, -118.1) -> District: Los Angeles County
# [10400/20640] Coordinates: (34.08, -118.05) -> District: Los Angeles County
# [10500/20640] Coordinates: (39.47, -121.54) -> District: Butte County
# [10600/20640] Coordinates: (33.67, -117.07) -> District: Riverside County
# [10700/20640] Coordinates: (33.6, -117.71) -> District: Orange County
# [10800/20640] Coordinates: (38.57, -121.49) -> District: Sacramento County
# [10900/20640] Coordinates: (34.29, -119.27) -> District: Ventura County
# [11000/20640] Coordinates: (33.79, -118.14) -> District: Los Angeles County
# [11100/20640] Coordinates: (40.79, -124.13) -> District: Humboldt County
# [11200/20640] Coordinates: (33.73, -117.94) -> District: Orange County
# [11300/20640] Coordinates: (39.78, -121.57) -> District: Butte County
# [11400/20640] Coordinates: (33.79, -118.25) -> District: Los Angeles County
# [11500/20640] Coordinates: (34.08, -118.17) -> District: Los Angeles County
# [11600/20640] Coordinates: (34.07, -118.23) -> District: Los Angeles County
# [11700/20640] Coordinates: (39.33, -123.23) -> District: Mendocino County
# [11800/20640] Coordinates: (33.02, -116.84) -> District: San Diego County
# [11900/20640] Coordinates: (33.73, -117.86) -> District: Orange County
# [12000/20640] Coordinates: (37.78, -122.21) -> District: Alameda County
# [12100/20640] Coordinates: (37.64, -121.0) -> District: Stanislaus County
# [12200/20640] Coordinates: (37.96, -121.26) -> District: San Joaquin County
# [12300/20640] Coordinates: (33.94, -118.3) -> District: Los Angeles County
# [12400/20640] Coordinates: (32.7, -117.13) -> District: San Diego County
# [12500/20640] Coordinates: (32.79, -117.03) -> District: San Diego County
# [12600/20640] Coordinates: (33.7, -117.78) -> District: Orange County
# [12700/20640] Coordinates: (37.35, -122.02) -> District: Santa Clara County
# [12800/20640] Coordinates: (34.25, -118.4) -> District: Los Angeles County
# [12900/20640] Coordinates: (38.16, -121.16) -> District: San Joaquin County
# [13000/20640] Coordinates: (33.23, -117.3) -> District: San Diego County
# [13100/20640] Coordinates: (34.02, -118.19) -> District: Los Angeles County
# [13200/20640] Coordinates: (34.1, -118.17) -> District: Los Angeles County
# [13300/20640] Coordinates: (34.86, -120.45) -> District: Santa Barbara County
# [13400/20640] Coordinates: (33.92, -118.24) -> District: Los Angeles County
# [13500/20640] Coordinates: (37.78, -122.21) -> District: Alameda County
# [13600/20640] Coordinates: (37.45, -122.25) -> District: San Mateo County
# [13700/20640] Coordinates: (33.96, -117.38) -> District: Riverside County
# [13800/20640] Coordinates: (33.97, -118.17) -> District: Los Angeles County
# [13900/20640] Coordinates: (34.65, -120.47) -> District: Santa Barbara County
# [14000/20640] Coordinates: (38.5, -121.42) -> District: Sacramento County
# [14100/20640] Coordinates: (37.73, -122.41) -> District: None
# [14200/20640] Coordinates: (33.96, -118.1) -> District: Los Angeles County
# [14300/20640] Coordinates: (34.13, -118.19) -> District: Los Angeles County
# [14400/20640] Coordinates: (34.47, -119.7) -> District: Santa Barbara County
# [14500/20640] Coordinates: (32.81, -117.05) -> District: San Diego County
# [14600/20640] Coordinates: (38.55, -121.78) -> District: Yolo County
# [14700/20640] Coordinates: (34.15, -119.16) -> District: Ventura County
# [14800/20640] Coordinates: (34.96, -120.45) -> District: Santa Barbara County
# [14900/20640] Coordinates: (34.08, -117.98) -> District: Los Angeles County
# [15000/20640] Coordinates: (32.75, -116.91) -> District: San Diego County
# [15100/20640] Coordinates: (33.94, -118.21) -> District: Los Angeles County
# [15200/20640] Coordinates: (33.9, -117.96) -> District: Orange County
# [15300/20640] Coordinates: (33.93, -118.37) -> District: Los Angeles County
# [15400/20640] Coordinates: (34.15, -117.66) -> District: San Bernardino County
# [15500/20640] Coordinates: (33.96, -117.39) -> District: Riverside County
# [15600/20640] Coordinates: (37.92, -122.35) -> District: Contra Costa County
# [15700/20640] Coordinates: (34.03, -117.31) -> District: San Bernardino County
# [15800/20640] Coordinates: (34.05, -118.34) -> District: Los Angeles County
# [15900/20640] Coordinates: (37.77, -122.42) -> District: None
# [16000/20640] Coordinates: (33.73, -116.93) -> District: Riverside County
# [16100/20640] Coordinates: (38.31, -122.28) -> District: Napa County
# [16200/20640] Coordinates: (37.8, -122.21) -> District: Alameda County
# [16300/20640] Coordinates: (37.53, -122.51) -> District: San Mateo County
# [16400/20640] Coordinates: (33.85, -118.38) -> District: Los Angeles County
# [16500/20640] Coordinates: (36.83, -119.77) -> District: Fresno County
# [16600/20640] Coordinates: (34.04, -117.96) -> District: Los Angeles County
# [16700/20640] Coordinates: (34.07, -116.47) -> District: San Bernardino County
# [16800/20640] Coordinates: (34.09, -118.25) -> District: Los Angeles County
# [16900/20640] Coordinates: (33.22, -117.33) -> District: San Diego County
# [17000/20640] Coordinates: (34.0, -118.34) -> District: Los Angeles County
# [17100/20640] Coordinates: (37.36, -122.1) -> District: Santa Clara County
# [17200/20640] Coordinates: (36.1, -119.06) -> District: Tulare County
# [17300/20640] Coordinates: (33.83, -117.81) -> District: Orange County
# [17400/20640] Coordinates: (38.56, -121.48) -> District: Sacramento County
# [17500/20640] Coordinates: (38.45, -122.74) -> District: Sonoma County
# [17600/20640] Coordinates: (34.09, -118.15) -> District: Los Angeles County
# [17700/20640] Coordinates: (37.45, -121.89) -> District: Santa Clara County
# [17800/20640] Coordinates: (33.93, -118.13) -> District: Los Angeles County
# [17900/20640] Coordinates: (35.19, -119.42) -> District: Kern County
# [18000/20640] Coordinates: (39.75, -121.84) -> District: Butte County
# [18100/20640] Coordinates: (33.64, -117.92) -> District: Orange County
# [18200/20640] Coordinates: (36.65, -119.8) -> District: Fresno County
# [18300/20640] Coordinates: (34.01, -118.26) -> District: Los Angeles County
# [18400/20640] Coordinates: (38.29, -122.3) -> District: Napa County
# [18500/20640] Coordinates: (34.23, -118.56) -> District: Los Angeles County
# [18600/20640] Coordinates: (32.76, -117.12) -> District: San Diego County
# [18700/20640] Coordinates: (37.36, -122.02) -> District: Santa Clara County
# [18800/20640] Coordinates: (36.96, -122.06) -> District: Santa Cruz County
# [18900/20640] Coordinates: (33.89, -118.07) -> District: Los Angeles County
# [19000/20640] Coordinates: (34.16, -118.29) -> District: Los Angeles County
# [19100/20640] Coordinates: (33.84, -117.98) -> District: Orange County
# [19200/20640] Coordinates: (33.8, -117.86) -> District: Orange County
# [19300/20640] Coordinates: (38.56, -121.53) -> District: Yolo County
# [19400/20640] Coordinates: (37.12, -122.12) -> District: Santa Cruz County
# [19500/20640] Coordinates: (34.0, -117.51) -> District: Riverside County
# [19600/20640] Coordinates: (33.61, -117.16) -> District: Riverside County
# [19700/20640] Coordinates: (33.96, -118.28) -> District: Los Angeles County
# [19800/20640] Coordinates: (33.74, -117.93) -> District: Orange County
# [19900/20640] Coordinates: (34.13, -117.3) -> District: San Bernardino County
# [20000/20640] Coordinates: (34.16, -119.17) -> District: Ventura County
# [20100/20640] Coordinates: (33.34, -117.21) -> District: San Diego County
# [20200/20640] Coordinates: (34.12, -118.2) -> District: Los Angeles County
# [20300/20640] Coordinates: (34.12, -117.35) -> District: San Bernardino County
# [20400/20640] Coordinates: (37.39, -121.87) -> District: Santa Clara County
# [20500/20640] Coordinates: (39.78, -121.63) -> District: Butte County
# [20600/20640] Coordinates: (39.16, -121.56) -> District: Yuba County
# [20640/20640] Coordinates: (39.37, -121.24) -> District: Yuba County

# %% [markdown]
# to get city level data through reverse gecoding. Not used, bacuase raw data is prepared at district level

# %%
# import requests
# import time
# import pickle
# import os

# # Load cache if it exists
# cache_file = "district_cache.pkl"
# if os.path.exists(cache_file):
#     with open(cache_file, "rb") as f:
#         cache = pickle.load(f)
# else:
#     cache = {}

# # Function to call Nominatim reverse geocoding API
# def get_district(lat, lon):
#     key = (round(lat, 2), round(lon, 2))  # Reduce precision to group nearby coords # all records are with 2 decimals

#     if key in cache:
#         return cache[key]

#     zoom_levels = [10, 11, 12]  # Try in order, # 10 usually returns a city, district/county level. Lower = broader (e.g., country), higher = more specific (e.g., house).

#     for zoom in zoom_levels:
#         url = "https://nominatim.openstreetmap.org/reverse"
#         params = {
#             "lat": lat,
#             "lon": lon,
#             "format": "json",
#             "zoom": zoom, 
#             "addressdetails": 1 # 1 returns a dictionary of address components (like city, state, district).
#         }
#         headers = {
#             "User-Agent": "darshilvekaria11@gmail.com"  # Required per Nominatim policy
#         }

#         try:
#             response = requests.get(url, params=params, headers=headers)
#             if response.status_code == 200:
#                 data = response.json()
#                 # print(data)
#                 district = data.get("address", {}).get("city")
#                 if district:
#                     cache[key] = district
#                     # Save updated cache
#                     with open(cache_file, "wb") as f:
#                         pickle.dump(cache, f)
#                     time.sleep(0.5)  # Respect Nominatim's 1 request/sec policy
#                     return district
#         except Exception as e:
#             print(f"Error during request: {e}")
#         time.sleep(0.5)  # Always sleep between retries to respect rate limit

#     return None  # If all zoom levels fail

# # housing_null = housing.loc[housing['district'].isna()]
# # print(housing_null)

# # Add a new column with district name
# cities = []
# for idx, row in housing.iterrows():
#     city = get_district(row["latitude"], row["longitude"])
#     cities.append(city)

#     # Print progress every 100 rows
#     # if (idx + 1) % 100 == 0 or (idx + 1) == len(housing):
#     print(f"[{idx + 1}/{len(housing)}] Coordinates: ({row['latitude']}, {row['longitude']}) -> city: {city}")

# housing["city"] = cities

# # Save the updated CSV
# housing.to_csv("housing_with_cities.csv", index=False)
